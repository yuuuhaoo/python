# %%
#單行註解 
a=6
b=3
print(a+b)

# %%
'''
多行註解
多行註解
'''

a=6
b=10
print(a+b)

# %%
#變數交換
x=1
y=10

z=x
x=y
y=z
print(x)
print(y)

# %%
#變數交換 不透過第3變數
x=1
y=10

x=x+y
y=x-y
x=x-y
print(x,y)

# %%
#變數的平行色定
x,y,z=1,10,100
print(x,y,z)

# %%
x,y,z=3,1,5
x+=1
y*=2
z**=3
print(x,y,z)
# Out:
# 4 2 125

# %%
import math 
r=10
print(r * r * math.pi)
# Out:
# 314.1592653589793

# %%
import math 
r=eval(input("請輸入園的半徑 :")) #eval()將字串轉換成數值運算
print(r * r * math.pi)
# Out:
# 請輸入園的半徑 :10
# 314.1592653589793

# %%
x=254
y=254.0
z="write"
print(type(x))
print(type(y))
print(type(z))
print(type(x==y))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
x=10
y=1
print(x/y) #求商
print(x//y) #求於數
# Out:
# 10.0
# 10

# %% [markdown]
# *算術符號順序*
#
# 1.   清單項目
# 2.   清單項目
#
#
# ()括號>**次方*/乘除>+*加減*

# %%
x=(5*(1+2)**2-3+4/2)
print(x)
# Out:
# 44.0

# %%
x="must"
print(type(x))
y=10
print(type(y))
print(10*y)
print(10*x)
z="10"
print(10*z)
print(10*int(z))
print(10*float(z))
print(10*str(y))
print(10*eval("5*2"))
# Out:
# <class 'str'>
# <class 'int'>
# 100
# mustmustmustmustmustmustmustmustmustmust
# 10101010101010101010
# 100
# 100.0
# 10101010101010101010
# 100

# %% [markdown]
# # **Print的三種方式**

# %%
a="This"+"is"+"a"+"book" #Thisisabook
print(a)
print("This","is","a","book")  #This is a book
# Out:
# Thisisabook
# This is a book
