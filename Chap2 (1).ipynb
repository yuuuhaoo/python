# %%
a=3
b=4

if a>b:
  print("a>b")
elif a==b:
  print("a=b")
else:
  print("a<b")
# Out:
# a<b

# %%
grade=87
print("成績評鑑: ")
if grade >= 90:
  print("優等")
elif grade >=80:
  print("甲等")
elif grade >=70:
  print("乙等")
elif grade >=60:
  print("丙等")
else:
  print("不及格")
# Out:
# 成績評鑑
# 甲等

# %%
for i in range(10):
  print(i)
for i in range(0,10,1):
  print(i)

# %%
for c in "I am a boy":
  print(c)
for p in ["java","phthon","c#"]:
  print(p)

# %%
sum=0
for i in range(1,11,1):
  sum+=i
  print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55

# %%
for chicken in range(0,36):
    rabbit=35-chicken
    if (2*chicken+4*rabbit) == 94:
        print("雞有",chicken,"隻,兔子有",rabbit,"隻")
        break
else:
    print("無解")
# Out:
# 雞有 23 隻,兔子有 12 隻

# %%
i=1
sum=0
while i < 11:
  sum+=i
  i+=1
  print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
